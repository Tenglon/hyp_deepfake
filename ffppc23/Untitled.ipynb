# %%
import os
import shutil

def copy_numeric_directories(src_path, dest_path):
    # 确保源路径存在
    if not os.path.exists(src_path):
        return "源路径不存在"

    # 如果目标路径不存在，则创建
    if not os.path.exists(dest_path):
        os.makedirs(dest_path)

    # 遍历源路径下的所有项
    for folder in os.listdir(src_path):
        folder_path = os.path.join(src_path, folder)

        # 检查是否为文件夹且名称仅由数字组成
        if os.path.isdir(folder_path) and folder.isdigit():
            dest_folder_path = os.path.join(dest_path, folder)

            # 复制文件夹
            shutil.copytree(folder_path, dest_folder_path)

    return "复制完成"

# 示例用法
for sets in ['train','val','test']: 
    src_path = "/var/scratch/achen/VisualSearch/ffppc23_clip_embeddings/{}".format(sets)  # 源路径
    dest_path = "/var/scratch/achen/VisualSearch/ffppc23/real/{}".format(sets)  # 目标路径
    copy_numeric_directories(src_path, dest_path)
    # print(result)
    print('frame num')
    print(len(get_files_with_extension(dest_path)))
    print('video num')
    print(len(list_directories(dest_path)))
    print("=="*10)
# Out:
# frame num
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 33
#      31 # print(result)
#      32 print('frame num')
# ---> 33 print(len(get_files_with_extension(dest_path)))
#      34 print('video num')
#      35 print(len(list_directories(dest_path)))
#
# NameError: name 'get_files_with_extension' is not defined

# %%
count =[]
for sets in ['train','val','test']: 
    # src_path = "/var/scratch/achen/VisualSearch/ffppc23_clip_embeddings/{}".format(sets)  # 源路径
    dest_path = "/var/scratch/achen/VisualSearch/ffppc23/real/{}".format(sets)  # 目标路径
    # copy_numeric_directories(src_path, dest_path)
    # print(result)
    print('frame num')
    print(len(get_files_with_extension(dest_path)))
    print('video num')
    print(len(list_directories(dest_path)))
    count.append(list_directories(dest_path))
    print("=="*10)
# Out:
# frame num
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 # copy_numeric_directories(src_path, dest_path)
#       6 # print(result)
#       7 print('frame num')
# ----> 8 print(len(get_files_with_extension(dest_path)))
#       9 print('video num')
#      10 print(len(list_directories(dest_path)))
#
# NameError: name 'get_files_with_extension' is not defined

# %%
import os
# p = '/var/scratch/achen/VisualSearch/ffppc23/real/all_videos_998'

root ='/var/scratch/achen/VisualSearch/ffppc23/real/real_new_split'



num_list =[]
cls = os.listdir(p)
for i in cls:
    # print(i)
    tp = len( os.listdir(os.path.join(p,i)))
    if tp<1:
        print(i)
        print(os.listdir(os.path.join(p,i)))
    num_list.append(tp)
    
total = sum(num_list)

# 找到最大值
max_value = max(num_list)

# 找到最小值
min_value = min(num_list)

print("总和:", total)
print("最大值:", max_value)
print("最小值:", min_value)


# 定义列表和指定的数字
numbers = num_list
specified_number = 10

# 统计大于指定数字的元素数量
count = len([num for num in numbers if num > specified_number])

print("大于", specified_number, "的元素数量是:", count)
# Out:
# 总和: 25734
# 最大值: 32
# 最小值: 3
# 大于 10 的元素数量是: 726

# %%
test = list(range(0,1000))
cls = [int(x) for x in cls]
num_list
# Out:
# [32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  30,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  30,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  17,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  18,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  24,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  27,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  28,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  3,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  19,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  20,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  4,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  15,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  8,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  8,
#  32,
#  16,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  30,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  20,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  9,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  12,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  20,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  20,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  9,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  21,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  21,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  32,
#  10,
#  32,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  32,
#  32,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  32,
#  10,
#  10,
#  10,
#  10,
#  32,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  7,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10]

# %%
print(set(test).difference(set(cls)))
# Out:
# {312, 267}
