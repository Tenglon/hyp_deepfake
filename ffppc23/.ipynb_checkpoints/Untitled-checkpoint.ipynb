# %%
import os
import shutil

def copy_numeric_directories(src_path, dest_path):
    # 确保源路径存在
    if not os.path.exists(src_path):
        return "源路径不存在"

    # 如果目标路径不存在，则创建
    if not os.path.exists(dest_path):
        os.makedirs(dest_path)

    # 遍历源路径下的所有项
    for folder in os.listdir(src_path):
        folder_path = os.path.join(src_path, folder)

        # 检查是否为文件夹且名称仅由数字组成
        if os.path.isdir(folder_path) and folder.isdigit():
            dest_folder_path = os.path.join(dest_path, folder)

            # 复制文件夹
            shutil.copytree(folder_path, dest_folder_path)

    return "复制完成"

# 示例用法
for sets in ['train','val','test']: 
    src_path = "/var/scratch/achen/VisualSearch/ffppc23_clip_embeddings/{}".format(sets)  # 源路径
    dest_path = "/var/scratch/achen/VisualSearch/ffppc23/real/{}".format(sets)  # 目标路径
    copy_numeric_directories(src_path, dest_path)
    # print(result)
    print('frame num')
    print(len(get_files_with_extension(dest_path)))
    print('video num')
    print(len(list_directories(dest_path)))
    print("=="*10)
# Out:
# frame num
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 33
#      31 # print(result)
#      32 print('frame num')
# ---> 33 print(len(get_files_with_extension(dest_path)))
#      34 print('video num')
#      35 print(len(list_directories(dest_path)))
#
# NameError: name 'get_files_with_extension' is not defined

# %%
count =[]
for sets in ['train','val','test']: 
    # src_path = "/var/scratch/achen/VisualSearch/ffppc23_clip_embeddings/{}".format(sets)  # 源路径
    dest_path = "/var/scratch/achen/VisualSearch/ffppc23/real/{}".format(sets)  # 目标路径
    # copy_numeric_directories(src_path, dest_path)
    # print(result)
    print('frame num')
    print(len(get_files_with_extension(dest_path)))
    print('video num')
    print(len(list_directories(dest_path)))
    count.append(list_directories(dest_path))
    print("=="*10)
# Out:
# frame num
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 # copy_numeric_directories(src_path, dest_path)
#       6 # print(result)
#       7 print('frame num')
# ----> 8 print(len(get_files_with_extension(dest_path)))
#       9 print('video num')
#      10 print(len(list_directories(dest_path)))
#
# NameError: name 'get_files_with_extension' is not defined

# %%
import os
p = '/var/scratch/achen/VisualSearch/ffppc23/real/all_videos_998'

num_list =[]
cls = os.listdir(p)
for i in cls:
    tp = len( os.listdir(os.path.join(p,i)))

# %%
cls
# Out:
# ['001',
#  '002',
#  '005',
#  '006',
#  '007',
#  '008',
#  '009',
#  '010',
#  '011',
#  '013',
#  '014',
#  '016',
#  '017',
#  '018',
#  '019',
#  '020',
#  '021',
#  '022',
#  '025',
#  '027',
#  '028',
#  '030',
#  '031',
#  '032',
#  '033',
#  '034',
#  '037',
#  '038',
#  '039',
#  '040',
#  '041',
#  '043',
#  '045',
#  '049',
#  '050',
#  '051',
#  '052',
#  '053',
#  '054',
#  '055',
#  '056',
#  '057',
#  '058',
#  '059',
#  '060',
#  '061',
#  '062',
#  '063',
#  '065',
#  '066',
#  '067',
#  '068',
#  '069',
#  '070',
#  '071',
#  '072',
#  '074',
#  '075',
#  '076',
#  '077',
#  '079',
#  '080',
#  '081',
#  '082',
#  '083',
#  '085',
#  '086',
#  '087',
#  '088',
#  '089',
#  '090',
#  '092',
#  '093',
#  '094',
#  '095',
#  '096',
#  '097',
#  '098',
#  '099',
#  '100',
#  '101',
#  '103',
#  '105',
#  '107',
#  '108',
#  '109',
#  '110',
#  '111',
#  '112',
#  '113',
#  '117',
#  '118',
#  '119',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '127',
#  '129',
#  '130',
#  '131',
#  '132',
#  '133',
#  '136',
#  '137',
#  '139',
#  '140',
#  '143',
#  '144',
#  '146',
#  '147',
#  '148',
#  '149',
#  '150',
#  '151',
#  '152',
#  '153',
#  '155',
#  '156',
#  '160',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '171',
#  '172',
#  '173',
#  '174',
#  '177',
#  '178',
#  '179',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '187',
#  '188',
#  '189',
#  '191',
#  '193',
#  '194',
#  '195',
#  '196',
#  '197',
#  '199',
#  '200',
#  '201',
#  '202',
#  '203',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '209',
#  '210',
#  '211',
#  '212',
#  '213',
#  '215',
#  '216',
#  '217',
#  '218',
#  '221',
#  '222',
#  '224',
#  '225',
#  '226',
#  '228',
#  '229',
#  '230',
#  '231',
#  '232',
#  '234',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '240',
#  '241',
#  '242',
#  '243',
#  '244',
#  '246',
#  '247',
#  '248',
#  '250',
#  '251',
#  '252',
#  '253',
#  '256',
#  '258',
#  '259',
#  '260',
#  '262',
#  '264',
#  '265',
#  '266',
#  '268',
#  '269',
#  '270',
#  '271',
#  '272',
#  '274',
#  '275',
#  '276',
#  '277',
#  '279',
#  '281',
#  '282',
#  '283',
#  '285',
#  '286',
#  '287',
#  '289',
#  '290',
#  '291',
#  '292',
#  '293',
#  '294',
#  '295',
#  '296',
#  '297',
#  '298',
#  '300',
#  '301',
#  '302',
#  '303',
#  '304',
#  '305',
#  '307',
#  '309',
#  '310',
#  '311',
#  '313',
#  '315',
#  '317',
#  '318',
#  '320',
#  '322',
#  '323',
#  '324',
#  '326',
#  '327',
#  '328',
#  '329',
#  '330',
#  '331',
#  '332',
#  '333',
#  '334',
#  '335',
#  '336',
#  '337',
#  '338',
#  '339',
#  '340',
#  '341',
#  '343',
#  '344',
#  '345',
#  '346',
#  '348',
#  '351',
#  '353',
#  '355',
#  '356',
#  '357',
#  '359',
#  '360',
#  '361',
#  '363',
#  '365',
#  '366',
#  '368',
#  '372',
#  '373',
#  '374',
#  '375',
#  '377',
#  '378',
#  '382',
#  '383',
#  '385',
#  '387',
#  '390',
#  '391',
#  '392',
#  '393',
#  '394',
#  '395',
#  '396',
#  '397',
#  '398',
#  '400',
#  '401',
#  '403',
#  '405',
#  '406',
#  '407',
#  '408',
#  '409',
#  '410',
#  '411',
#  '412',
#  '413',
#  '414',
#  '415',
#  '417',
#  '424',
#  '426',
#  '427',
#  '428',
#  '430',
#  '431',
#  '432',
#  '433',
#  '434',
#  '435',
#  '436',
#  '437',
#  '438',
#  '439',
#  '441',
#  '442',
#  '444',
#  '446',
#  '447',
#  '448',
#  '449',
#  '450',
#  '451',
#  '456',
#  '457',
#  '458',
#  '459',
#  '460',
#  '461',
#  '463',
#  '464',
#  '466',
#  '469',
#  '473',
#  '474',
#  '475',
#  '476',
#  '477',
#  '478',
#  '481',
#  '484',
#  '486',
#  '487',
#  '489',
#  '490',
#  '491',
#  '495',
#  '496',
#  '497',
#  '498',
#  '499',
#  '500',
#  '501',
#  '502',
#  '503',
#  '504',
#  '505',
#  '506',
#  '508',
#  '509',
#  '510',
#  '512',
#  '513',
#  '515',
#  '516',
#  '518',
#  '519',
#  '520',
#  '522',
#  '523',
#  '524',
#  '525',
#  '526',
#  '528',
#  '530',
#  '531',
#  '532',
#  '533',
#  '534',
#  '535',
#  '536',
#  '537',
#  '539',
#  '540',
#  '541',
#  '542',
#  '543',
#  '544',
#  '545',
#  '546',
#  '547',
#  '549',
#  '551',
#  '553',
#  '554',
#  '555',
#  '556',
#  '559',
#  '561',
#  '562',
#  '563',
#  '568',
#  '569',
#  '570',
#  '572',
#  '573',
#  '574',
#  '575',
#  '576',
#  '577',
#  '578',
#  '580',
#  '581',
#  '582',
#  '587',
#  '588',
#  '590',
#  '591',
#  '592',
#  '593',
#  '594',
#  '596',
#  '598',
#  '600',
#  '601',
#  '602',
#  '603',
#  '604',
#  '605',
#  '609',
#  '610',
#  '611',
#  '613',
#  '614',
#  '615',
#  '616',
#  '618',
#  '619',
#  '620',
#  '621',
#  '624',
#  '626',
#  '627',
#  '628',
#  '629',
#  '631',
#  '635',
#  '636',
#  '637',
#  '639',
#  '641',
#  '642',
#  '643',
#  '644',
#  '645',
#  '646',
#  '648',
#  '651',
#  '652',
#  '653',
#  '654',
#  '655',
#  '657',
#  '658',
#  '659',
#  '662',
#  '663',
#  '665',
#  '667',
#  '671',
#  '673',
#  '674',
#  '676',
#  '677',
#  '678',
#  '679',
#  '680',
#  '681',
#  '684',
#  '685',
#  '686',
#  '687',
#  '688',
#  '689',
#  '690',
#  '692',
#  '693',
#  '694',
#  '696',
#  '697',
#  '698',
#  '699',
#  '700',
#  '703',
#  '704',
#  '708',
#  '709',
#  '710',
#  '711',
#  '712',
#  '713',
#  '715',
#  '716',
#  '717',
#  '718',
#  '719',
#  '721',
#  '722',
#  '723',
#  '726',
#  '728',
#  '730',
#  '733',
#  '734',
#  '735',
#  '736',
#  '737',
#  '738',
#  '740',
#  '743',
#  '744',
#  '747',
#  '748',
#  '749',
#  '750',
#  '751',
#  '752',
#  '753',
#  '754',
#  '756',
#  '757',
#  '758',
#  '760',
#  '761',
#  '763',
#  '764',
#  '765',
#  '766',
#  '767',
#  '769',
#  '770',
#  '771',
#  '772',
#  '773',
#  '774',
#  '776',
#  '778',
#  '780',
#  '781',
#  '782',
#  '783',
#  '784',
#  '785',
#  '786',
#  '787',
#  '788',
#  '789',
#  '790',
#  '791',
#  '792',
#  '795',
#  '796',
#  '797',
#  '798',
#  '799',
#  '800',
#  '802',
#  '803',
#  '804',
#  '805',
#  '806',
#  '808',
#  '809',
#  '810',
#  '811',
#  '813',
#  '814',
#  '815',
#  '819',
#  '822',
#  '825',
#  '826',
#  '828',
#  '829',
#  '830',
#  '831',
#  '833',
#  '835',
#  '836',
#  '838',
#  '839',
#  '840',
#  '841',
#  '843',
#  '844',
#  '845',
#  '846',
#  '848',
#  '849',
#  '850',
#  '853',
#  '854',
#  '856',
#  '858',
#  '859',
#  '860',
#  '861',
#  '863',
#  '864',
#  '866',
#  '867',
#  '869',
#  '870',
#  '871',
#  '872',
#  '873',
#  '874',
#  '876',
#  '877',
#  '878',
#  '879',
#  '881',
#  '882',
#  '883',
#  '884',
#  '885',
#  '886',
#  '887',
#  '888',
#  '889',
#  '891',
#  '892',
#  '893',
#  '894',
#  '897',
#  '899',
#  '901',
#  '902',
#  '903',
#  '905',
#  '907',
#  '908',
#  '910',
#  '911',
#  '913',
#  '914',
#  '916',
#  '918',
#  '920',
#  '921',
#  '928',
#  '929',
#  '930',
#  '931',
#  '934',
#  '935',
#  '936',
#  '937',
#  '938',
#  '940',
#  '941',
#  '942',
#  '943',
#  '944',
#  '946',
#  '948',
#  '950',
#  '952',
#  '954',
#  '957',
#  '959',
#  '960',
#  '961',
#  '962',
#  '963',
#  '964',
#  '965',
#  '966',
#  '967',
#  '968',
#  '969',
#  '972',
#  '975',
#  '976',
#  '977',
#  '978',
#  '981',
#  '983',
#  '984',
#  '985',
#  '986',
#  '987',
#  '988',
#  '989',
#  '990',
#  '993',
#  '994',
#  '996',
#  '997',
#  '998',
#  '999',
#  '000',
#  '003',
#  '012',
#  '015',
#  '024',
#  '026',
#  '029',
#  '035',
#  '036',
#  '044',
#  '047',
#  '048',
#  '073',
#  '078',
#  '102',
#  '114',
#  '128',
#  '135',
#  '138',
#  '141',
#  '142',
#  '154',
#  '158',
#  '161',
#  '169',
#  '170',
#  '176',
#  '186',
#  '190',
#  '214',
#  '219',
#  '220',
#  '227',
#  '233',
#  '249',
#  '255',
#  '257',
#  '278',
#  '280',
#  '288',
#  '306',
#  '308',
#  '314',
#  '319',
#  '321',
#  '347',
#  '352',
#  '358',
#  '367',
#  '371',
#  '376',
#  '379',
#  '380',
#  '381',
#  '384',
#  '386',
#  '388',
#  '389',
#  '399',
#  '404',
#  '418',
#  '420',
#  '421',
#  '422',
#  '423',
#  '425',
#  '429',
#  '445',
#  '452',
#  '454',
#  '462',
#  '467',
#  '479',
#  '480',
#  '485',
#  '488',
#  '494',
#  '507',
#  '517',
#  '521',
#  '527',
#  '529',
#  '550',
#  '552',
#  '579',
#  '607',
#  '608',
#  '623',
#  '625',
#  '630',
#  '633',
#  '634',
#  '650',
#  '660',
#  '661',
#  '669',
#  '670',
#  '675',
#  '682',
#  '683',
#  '691',
#  '695',
#  '701',
#  '705',
#  '706',
#  '707',
#  '714',
#  '724',
#  '725',
#  '731',
#  '732',
#  '739',
#  '741',
#  '755',
#  '759',
#  '801',
#  '812',
#  '821',
#  '842',
#  '847',
#  '851',
#  '855',
#  '862',
#  '865',
#  '868',
#  '880',
#  '896',
#  '906',
#  '917',
#  '919',
#  '924',
#  '932',
#  '945',
#  '949',
#  '953',
#  '955',
#  '970',
#  '973',
#  '974',
#  '995',
#  '004',
#  '023',
#  '042',
#  '046',
#  '064',
#  '084',
#  '091',
#  '104',
#  '106',
#  '115',
#  '116',
#  '126',
#  '134',
#  '145',
#  '157',
#  '159',
#  '175',
#  '192',
#  '198',
#  '223',
#  '245',
#  '254',
#  '261',
#  '263',
#  '273',
#  '284',
#  '299',
#  '316',
#  '325',
#  '342',
#  '349',
#  '350',
#  '354',
#  '362',
#  '364',
#  '369',
#  '370',
#  '402',
#  '416',
#  '419',
#  '440',
#  '443',
#  '453',
#  '455',
#  '465',
#  '468',
#  '470',
#  '471',
#  '472',
#  '482',
#  '483',
#  '492',
#  '493',
#  '511',
#  '514',
#  '538',
#  '548',
#  '557',
#  '558',
#  '560',
#  '564',
#  '565',
#  '566',
#  '567',
#  '571',
#  '583',
#  '584',
#  '585',
#  '586',
#  '589',
#  '595',
#  '597',
#  '599',
#  '606',
#  '612',
#  '617',
#  '622',
#  '632',
#  '638',
#  '640',
#  '647',
#  '649',
#  '656',
#  '664',
#  '666',
#  '668',
#  '672',
#  '702',
#  '720',
#  '727',
#  '729',
#  '742',
#  '745',
#  '746',
#  '762',
#  '768',
#  '775',
#  '777',
#  '779',
#  '793',
#  '794',
#  '807',
#  '816',
#  '817',
#  '818',
#  '820',
#  '823',
#  '824',
#  '827',
#  '832',
#  '834',
#  '837',
#  '852',
#  '857',
#  '875',
#  '890',
#  '895',
#  '898',
#  '900',
#  '904',
#  '909',
#  '912',
#  '915',
#  '922',
#  '923',
#  '925',
#  '926',
#  '927',
#  '933',
#  '939',
#  '947',
#  '951',
#  '956',
#  '958',
#  '971',
#  '979',
#  '980',
#  '982',
#  '991',
#  '992',
#  'train',
#  'val',
#  ...]
